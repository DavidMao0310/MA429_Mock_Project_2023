# %% [markdown]
# # Start from the dataset with column names, and the weights of instances have been dropped

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import entropy
from scipy.stats import chi2_contingency
import seaborn as sns
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_path = '/content/drive/MyDrive/MA429/Mock_Project/'
data = pd.read_csv(data_path+'train_with_na.csv')
data
# Out:
#         age                     class_worker  det_ind_code  det_occ_code  \
# 0        73                  Not in universe             0             0
# 1        58   Self-employed-not incorporated             4            34
# 2        18                  Not in universe             0             0
# 3         9                  Not in universe             0             0
# 4        10                  Not in universe             0             0
# ...     ...                              ...           ...           ...
# 199518   87                  Not in universe             0             0
# 199519   65       Self-employed-incorporated            37             2
# 199520   47                  Not in universe             0             0
# 199521   16                  Not in universe             0             0
# 199522   32                          Private            42            30
#
#                           education  wage_per_hour        hs_college  \
# 0              High school graduate              0   Not in universe
# 1        Some college but no degree              0   Not in universe
# 2                        10th grade              0       High school
# 3                          Children              0   Not in universe
# 4                          Children              0   Not in universe
# ...                             ...            ...               ...
# 199518            7th and 8th grade              0   Not in universe
# 199519                   11th grade              0   Not in universe
# 199520   Some college but no degree              0   Not in universe
# 199521                   10th grade              0       High school
# 199522         High school graduate              0   Not in universe
#
#                             marital_stat                 major_ind_code  \
# 0                                Widowed    Not in universe or children
# 1                               Divorced                   Construction
# 2                          Never married    Not in universe or children
# 3                          Never married    Not in universe or children
# 4                          Never married    Not in universe or children
# ...                                  ...                            ...
# 199518   Married-civilian spouse present    Not in universe or children
# 199519   Married-civilian spouse present   Business and repair services
# 199520   Married-civilian spouse present    Not in universe or children
# 199521                     Never married    Not in universe or children
# 199522                     Never married        Medical except hospital
#
#                               major_occ_code  ...  country_father  \
# 0                            Not in universe  ...   United-States
# 1        Precision production craft & repair  ...   United-States
# 2                            Not in universe  ...         Vietnam
# 3                            Not in universe  ...   United-States
# 4                            Not in universe  ...   United-States
# ...                                      ...  ...             ...
# 199518                       Not in universe  ...          Canada
# 199519        Executive admin and managerial  ...   United-States
# 199520                       Not in universe  ...          Poland
# 199521                       Not in universe  ...   United-States
# 199522                         Other service  ...             NaN
#
#         country_mother    country_self  \
# 0        United-States   United-States
# 1        United-States   United-States
# 2              Vietnam         Vietnam
# 3        United-States   United-States
# 4        United-States   United-States
# ...                ...             ...
# 199518   United-States   United-States
# 199519   United-States   United-States
# 199520          Poland         Germany
# 199521   United-States   United-States
# 199522             NaN             NaN
#
#                                          citizenship own_or_self  \
# 0                  Native- Born in the United States           0
# 1                  Native- Born in the United States           0
# 2                Foreign born- Not a citizen of U S            0
# 3                  Native- Born in the United States           0
# 4                  Native- Born in the United States           0
# ...                                              ...         ...
# 199518             Native- Born in the United States           0
# 199519             Native- Born in the United States           0
# 199520   Foreign born- U S citizen by naturalization           0
# 199521             Native- Born in the United States           0
# 199522           Foreign born- Not a citizen of U S            0
#
#             vet_question  vet_benefits  weeks_worked  year income_50k
# 0        Not in universe             2             0    95     -50000
# 1        Not in universe             2            52    94     -50000
# 2        Not in universe             2             0    95     -50000
# 3        Not in universe             0             0    94     -50000
# 4        Not in universe             0             0    94     -50000
# ...                  ...           ...           ...   ...        ...
# 199518   Not in universe             2             0    95     -50000
# 199519   Not in universe             2            52    94     -50000
# 199520   Not in universe             2            52    95     -50000
# 199521   Not in universe             2             0    95     -50000
# 199522   Not in universe             2            52    94     -50000
#
# [199523 rows x 41 columns]

# %% [markdown]
# # EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199523 entries, 0 to 199522
# Data columns (total 41 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   age               199523 non-null  int64
#  1   class_worker      199523 non-null  object
#  2   det_ind_code      199523 non-null  int64
#  3   det_occ_code      199523 non-null  int64
#  4   education         199523 non-null  object
#  5   wage_per_hour     199523 non-null  int64
#  6   hs_college        199523 non-null  object
#  7   marital_stat      199523 non-null  object
#  8   major_ind_code    199523 non-null  object
#  9   major_occ_code    199523 non-null  object
#  10  race              199523 non-null  object
#  11  hisp_origin       199523 non-null  object
#  12  sex               199523 non-null  object
#  13  union_member      199523 non-null  object
#  14  unemp_reason      199523 non-null  object
#  15  full_or_part_emp  199523 non-null  object
#  16  capital_gains     199523 non-null  int64
#  17  capital_losses    199523 non-null  int64
#  18  stock_dividends   199523 non-null  int64
#  19  tax_filer_stat    199523 non-null  object
#  20  region_prev_res   199523 non-null  object
#  21  state_prev_res    198815 non-null  object
#  22  det_hh_fam_stat   199523 non-null  object
#  23  det_hh_summ       199523 non-null  object
#  24  mig_chg_msa       99827 non-null   object
#  25  mig_chg_reg       99827 non-null   object
#  26  mig_move_reg      99827 non-null   object
#  27  mig_same          199523 non-null  object
#  28  mig_prev_sunbelt  99827 non-null   object
#  29  num_emp           199523 non-null  int64
#  30  fam_under_18      199523 non-null  object
#  31  country_father    192810 non-null  object
#  32  country_mother    193404 non-null  object
#  33  country_self      196130 non-null  object
#  34  citizenship       199523 non-null  object
#  35  own_or_self       199523 non-null  int64
#  36  vet_question      199523 non-null  object
#  37  vet_benefits      199523 non-null  int64
#  38  weeks_worked      199523 non-null  int64
#  39  year              199523 non-null  int64
#  40  income_50k        199523 non-null  object
# dtypes: int64(12), object(29)
# memory usage: 62.4+ MB

# %% [markdown]
# #### Following is the summary for numerical features

# %%
data.describe()
# Out:
#                  age   det_ind_code   det_occ_code  wage_per_hour  \
# count  199523.000000  199523.000000  199523.000000  199523.000000
# mean       34.494199      15.352320      11.306556      55.426908
# std        22.310895      18.067129      14.454204     274.896454
# min         0.000000       0.000000       0.000000       0.000000
# 25%        15.000000       0.000000       0.000000       0.000000
# 50%        33.000000       0.000000       0.000000       0.000000
# 75%        50.000000      33.000000      26.000000       0.000000
# max        90.000000      51.000000      46.000000    9999.000000
#
#        capital_gains  capital_losses  stock_dividends        num_emp  \
# count   199523.00000   199523.000000    199523.000000  199523.000000
# mean       434.71899       37.313788       197.529533       1.956180
# std       4697.53128      271.896428      1984.163658       2.365126
# min          0.00000        0.000000         0.000000       0.000000
# 25%          0.00000        0.000000         0.000000       0.000000
# 50%          0.00000        0.000000         0.000000       1.000000
# 75%          0.00000        0.000000         0.000000       4.000000
# max      99999.00000     4608.000000     99999.000000       6.000000
#
#          own_or_self   vet_benefits   weeks_worked           year
# count  199523.000000  199523.000000  199523.000000  199523.000000
# mean        0.175438       1.514833      23.174897      94.499672
# std         0.553694       0.851473      24.411488       0.500001
# min         0.000000       0.000000       0.000000      94.000000
# 25%         0.000000       2.000000       0.000000      94.000000
# 50%         0.000000       2.000000       8.000000      94.000000
# 75%         0.000000       2.000000      52.000000      95.000000
# max         2.000000       2.000000      52.000000      95.000000

# %% [markdown]
# #### Detect the NA value

# %%
data.isna().sum()
# Out:
# age                     0
# class_worker            0
# det_ind_code            0
# det_occ_code            0
# education               0
# wage_per_hour           0
# hs_college              0
# marital_stat            0
# major_ind_code          0
# major_occ_code          0
# race                    0
# hisp_origin             0
# sex                     0
# union_member            0
# unemp_reason            0
# full_or_part_emp        0
# capital_gains           0
# capital_losses          0
# stock_dividends         0
# tax_filer_stat          0
# region_prev_res         0
# state_prev_res        708
# det_hh_fam_stat         0
# det_hh_summ             0
# mig_chg_msa         99696
# mig_chg_reg         99696
# mig_move_reg        99696
# mig_same                0
# mig_prev_sunbelt    99696
# num_emp                 0
# fam_under_18            0
# country_father       6713
# country_mother       6119
# country_self         3393
# citizenship             0
# own_or_self             0
# vet_question            0
# vet_benefits            0
# weeks_worked            0
# year                    0
# income_50k              0
# dtype: int64

# %% [markdown]
# ### Based on the type of data, we group the categorical data and numerical data

# %%
cat_cols = data.select_dtypes(include=['object']).columns
num_cols = data.select_dtypes(include=['number']).columns
data_cat = data[cat_cols]
data_num = data[num_cols]

# %% [markdown]
# #### Is any NA in the numerical variables

# %%
data_num.isna().sum()
# Out:
# age                0
# det_ind_code       0
# det_occ_code       0
# wage_per_hour      0
# capital_gains      0
# capital_losses     0
# stock_dividends    0
# num_emp            0
# own_or_self        0
# vet_benefits       0
# weeks_worked       0
# year               0
# dtype: int64

# %% [markdown]
# As we can see, there is no NA value in numerical variables, and the number of different values is given following.

# %%
data_num.nunique()
# Out:
# age                  91
# det_ind_code         52
# det_occ_code         47
# wage_per_hour      1240
# capital_gains       132
# capital_losses      113
# stock_dividends    1478
# num_emp               7
# own_or_self           3
# vet_benefits          3
# weeks_worked         53
# year                  2
# dtype: int64

# %% [markdown]
# #### Is any NA in the categorical variables, if so then we fill NA

# %%
data_cat.isna().sum()
# Out:
# class_worker            0
# education               0
# hs_college              0
# marital_stat            0
# major_ind_code          0
# major_occ_code          0
# race                    0
# hisp_origin             0
# sex                     0
# union_member            0
# unemp_reason            0
# full_or_part_emp        0
# tax_filer_stat          0
# region_prev_res         0
# state_prev_res        708
# det_hh_fam_stat         0
# det_hh_summ             0
# mig_chg_msa         99696
# mig_chg_reg         99696
# mig_move_reg        99696
# mig_same                0
# mig_prev_sunbelt    99696
# fam_under_18            0
# country_father       6713
# country_mother       6119
# country_self         3393
# citizenship             0
# vet_question            0
# income_50k              0
# dtype: int64

# %% [markdown]
# ## Noticed that this part should be in the part 'data preprocessing-missing value'

# %% [markdown]
# * Rules: We drop the missing value if the proportion of missing value is > 30%

# %%
def drop_cate_na_by_proportion(df):
    NA_features_drop = df.isna().sum()[df.isna().sum() / df.shape[0] >= 0.3].index.tolist()
    df1 = df.drop(NA_features_drop, axis=1)
    return df1

# %%
data_cat = drop_cate_na_by_proportion(data_cat)

# %% [markdown]
# ## This part should be in 'selecting missing values'

# %% [markdown]
# By contextual meaning, we find that the country_father and country_mother have less connection to the self income. We shall drop them all.

# %%
data_cat = data_cat.drop(['country_father', 'country_mother'], axis=1)

# %% [markdown]
# Check the categorical data

# %%
data_cat.isna().sum()
# Out:
# class_worker           0
# education              0
# hs_college             0
# marital_stat           0
# major_ind_code         0
# major_occ_code         0
# race                   0
# hisp_origin            0
# sex                    0
# union_member           0
# unemp_reason           0
# full_or_part_emp       0
# tax_filer_stat         0
# region_prev_res        0
# state_prev_res       708
# det_hh_fam_stat        0
# det_hh_summ            0
# mig_same               0
# fam_under_18           0
# country_self        3393
# citizenship            0
# vet_question           0
# income_50k             0
# dtype: int64

# %% [markdown]
# * We fill NA by mode (i.e. high frequency)

# %%
data_cat['country_self'] = data_cat['country_self'].fillna(data_cat['country_self'].mode()[0])
data_cat['state_prev_res'] = data_cat['state_prev_res'].fillna(data_cat['state_prev_res'].mode()[0])

# %%
data_cat
# Out:
#                            class_worker                    education  \
# 0                       Not in universe         High school graduate
# 1        Self-employed-not incorporated   Some college but no degree
# 2                       Not in universe                   10th grade
# 3                       Not in universe                     Children
# 4                       Not in universe                     Children
# ...                                 ...                          ...
# 199518                  Not in universe            7th and 8th grade
# 199519       Self-employed-incorporated                   11th grade
# 199520                  Not in universe   Some college but no degree
# 199521                  Not in universe                   10th grade
# 199522                          Private         High school graduate
#
#               hs_college                      marital_stat  \
# 0        Not in universe                           Widowed
# 1        Not in universe                          Divorced
# 2            High school                     Never married
# 3        Not in universe                     Never married
# 4        Not in universe                     Never married
# ...                  ...                               ...
# 199518   Not in universe   Married-civilian spouse present
# 199519   Not in universe   Married-civilian spouse present
# 199520   Not in universe   Married-civilian spouse present
# 199521       High school                     Never married
# 199522   Not in universe                     Never married
#
#                        major_ind_code                        major_occ_code  \
# 0         Not in universe or children                       Not in universe
# 1                        Construction   Precision production craft & repair
# 2         Not in universe or children                       Not in universe
# 3         Not in universe or children                       Not in universe
# 4         Not in universe or children                       Not in universe
# ...                               ...                                   ...
# 199518    Not in universe or children                       Not in universe
# 199519   Business and repair services        Executive admin and managerial
# 199520    Not in universe or children                       Not in universe
# 199521    Not in universe or children                       Not in universe
# 199522        Medical except hospital                         Other service
#
#                               race hisp_origin      sex      union_member  \
# 0                            White   All other   Female   Not in universe
# 1                            White   All other     Male   Not in universe
# 2        Asian or Pacific Islander   All other   Female   Not in universe
# 3                            White   All other   Female   Not in universe
# 4                            White   All other   Female   Not in universe
# ...                            ...         ...      ...               ...
# 199518                       White   All other     Male   Not in universe
# 199519                       White   All other     Male   Not in universe
# 199520                       White   All other     Male   Not in universe
# 199521                       White   All other   Female   Not in universe
# 199522                       Black   All other   Female                No
#
#         ...   region_prev_res    state_prev_res  \
# 0       ...   Not in universe   Not in universe
# 1       ...             South          Arkansas
# 2       ...   Not in universe   Not in universe
# 3       ...   Not in universe   Not in universe
# 4       ...   Not in universe   Not in universe
# ...     ...               ...               ...
# 199518  ...   Not in universe   Not in universe
# 199519  ...   Not in universe   Not in universe
# 199520  ...   Not in universe   Not in universe
# 199521  ...   Not in universe   Not in universe
# 199522  ...   Not in universe   Not in universe
#
#                                   det_hh_fam_stat  \
# 0        Other Rel 18+ ever marr not in subfamily
# 1                                     Householder
# 2         Child 18+ never marr Not in a subfamily
# 3           Child <18 never marr not in subfamily
# 4           Child <18 never marr not in subfamily
# ...                                           ...
# 199518                                Householder
# 199519                                Householder
# 199520                                Householder
# 199521      Child <18 never marr not in subfamily
# 199522                      Nonfamily householder
#
#                            det_hh_summ                           mig_same  \
# 0        Other relative of householder   Not in universe under 1 year old
# 1                          Householder                                 No
# 2                    Child 18 or older   Not in universe under 1 year old
# 3         Child under 18 never married                                Yes
# 4         Child under 18 never married                                Yes
# ...                                ...                                ...
# 199518                     Householder   Not in universe under 1 year old
# 199519                     Householder                                Yes
# 199520                     Householder   Not in universe under 1 year old
# 199521    Child under 18 never married   Not in universe under 1 year old
# 199522                     Householder                                Yes
#
#                  fam_under_18    country_self  \
# 0             Not in universe   United-States
# 1             Not in universe   United-States
# 2             Not in universe         Vietnam
# 3        Both parents present   United-States
# 4        Both parents present   United-States
# ...                       ...             ...
# 199518        Not in universe   United-States
# 199519        Not in universe   United-States
# 199520        Not in universe         Germany
# 199521   Both parents present   United-States
# 199522        Not in universe   United-States
#
#                                          citizenship      vet_question  \
# 0                  Native- Born in the United States   Not in universe
# 1                  Native- Born in the United States   Not in universe
# 2                Foreign born- Not a citizen of U S    Not in universe
# 3                  Native- Born in the United States   Not in universe
# 4                  Native- Born in the United States   Not in universe
# ...                                              ...               ...
# 199518             Native- Born in the United States   Not in universe
# 199519             Native- Born in the United States   Not in universe
# 199520   Foreign born- U S citizen by naturalization   Not in universe
# 199521             Native- Born in the United States   Not in universe
# 199522           Foreign born- Not a citizen of U S    Not in universe
#
#        income_50k
# 0          -50000
# 1          -50000
# 2          -50000
# 3          -50000
# 4          -50000
# ...           ...
# 199518     -50000
# 199519     -50000
# 199520     -50000
# 199521     -50000
# 199522     -50000
#
# [199523 rows x 23 columns]

# %% [markdown]
# ### Then we need to identify the 'Not in Universe', since it may cause highly imbalanced in training

# %% [markdown]
# # Here we go back to EDA part, some useful plot to identidy some useful characteristic of data

# %% [markdown]
# ### Some useful plots

# %%
def plot_work_class_age(df):
    try:
        sns.boxplot(x=df['age'], y=df['class_worker'])
        plt.tight_layout()
        plt.show()
    except:
        print('No class_worker or age')
    try:
        sns.boxplot(x=df['age'], y=df['major_occ_code'])
        plt.tight_layout()
        plt.show()
    except:
        print('No major_occ_code or age')


plot_work_class_age(data)

# %%
def plot_count_income_class(df):
    col_list = ["full_or_part_emp", "education", "sex", "race", "tax_filer_stat"]
    for col in col_list:
        sns.countplot(x=col, hue='income_50k', data=df)
        plt.title(col)
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()


plot_count_income_class(data_cat)

# %%
def plot_income_age(df):
    try:
        age_income_plot = sns.FacetGrid(df, col='income_50k')
        age_income_plot.map(sns.distplot, 'age')
        #sns.histplot(df["flipper_length_mm"], kde=True, stat="density")
        plt.tight_layout()
        plt.show()
    except:
        print('No income_50k or age')


plot_income_age(data)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
def plot_income_weeks_work(df):
    try:
        age_income_plot = sns.FacetGrid(df, col='income_50k')
        age_income_plot.map(sns.distplot, 'weeks_worked')
        plt.tight_layout()
        plt.show()
    except:
        print('No weeks_worked or age')


plot_income_weeks_work(data)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
def plot_income_stock_div(df):
    try:
        age_income_plot = sns.FacetGrid(df, col='income_50k')
        age_income_plot.map(sns.distplot, 'stock_dividends')
        plt.tight_layout()
        plt.show()
    except:
        print('No stock_dividends or age')


plot_income_stock_div(data)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# ## check distribution for numericial data plots

# %%
data_num.nunique()
# Out:
# age                  91
# det_ind_code         52
# det_occ_code         47
# wage_per_hour      1240
# capital_gains       132
# capital_losses      113
# stock_dividends    1478
# num_emp               7
# own_or_self           3
# vet_benefits          3
# weeks_worked         53
# year                  2
# dtype: int64

# %%
sns.pairplot(data_num[['age',
 'wage_per_hour',
 'capital_gains',
 'capital_losses',
 'stock_dividends',
 'weeks_worked']])
plt.show()

# %%
for i in ['age','wage_per_hour','capital_gains','capital_losses','stock_dividends','weeks_worked']:
 sns.violinplot(data_num[i],)
 plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# #### Outliers analysis?

# %%
def drop_outliers(df, z_thresh):
    """
    Identify and drop outliers in a dataframe based on the z-score method
    """
    df_copy = df.copy()
    z_scores = df_copy.apply(lambda x: np.abs((x - x.mean()) / x.std()))
    df_copy = df_copy[(z_scores < z_thresh).all(axis=1)]
    return df_copy

# %% [markdown]
# # Noticed that here we drop some variables by contextual meaning, when we write the report we can say we select some important variables to plot, then do EDA

# %% [markdown]
# ## Since some columns may provide same information, so we need to identify which colunms should be dropped, by determining there correlation with Cramer's V
#
# ### For continuous variables
#
# * From the context, we find "det_ind_code" and "det_occ_code" in continuous features, representing the industry and occupation code, which are similar to the 'major_ind_code', 'major_occ_code' in categorical features, then we may only keep the categorical representation.

# %%
data_num = data_num.drop(['det_ind_code', 'det_occ_code'], axis=1)
data_num
# Out:
#         age  wage_per_hour  capital_gains  capital_losses  stock_dividends  \
# 0        73              0              0               0                0
# 1        58              0              0               0                0
# 2        18              0              0               0                0
# 3         9              0              0               0                0
# 4        10              0              0               0                0
# ...     ...            ...            ...             ...              ...
# 199518   87              0              0               0                0
# 199519   65              0           6418               0                9
# 199520   47              0              0               0              157
# 199521   16              0              0               0                0
# 199522   32              0              0               0                0
#
#         num_emp  own_or_self  vet_benefits  weeks_worked  year
# 0             0            0             2             0    95
# 1             1            0             2            52    94
# 2             0            0             2             0    95
# 3             0            0             0             0    94
# 4             0            0             0             0    94
# ...         ...          ...           ...           ...   ...
# 199518        0            0             2             0    95
# 199519        1            0             2            52    94
# 199520        6            0             2            52    95
# 199521        0            0             2             0    95
# 199522        6            0             2            52    94
#
# [199523 rows x 10 columns]

# %%
corr_num1 = data_num.corr()
sns.heatmap(corr_num1,annot=True, fmt = ".2f", cmap = "coolwarm")
# plt.title('Correlation between continuous variables')
plt.show()

# %%
corr_num_helper1 = data_num[['vet_benefits', 'num_emp', 'own_or_self']].corr()
sns.heatmap(corr_num_helper1,annot=True, fmt = ".2f", cmap = "coolwarm")
plt.show()

# %% [markdown]
# * From the heatmap, we found that the "vet_benefits" has high correlation with the "age" and "num_emp", then we shall drop this variable
# * "num_emp" to be determined LATER!!!, In procssing part we will disscuss this again.

# %%
data_num = data_num.drop(['vet_benefits'], axis=1)

# %% [markdown]
# # Here we check correlation between categorical variables, by some plots

# %%
data_cat
# Out:
#                            class_worker                    education  \
# 0                       Not in universe         High school graduate
# 1        Self-employed-not incorporated   Some college but no degree
# 2                       Not in universe                   10th grade
# 3                       Not in universe                     Children
# 4                       Not in universe                     Children
# ...                                 ...                          ...
# 199518                  Not in universe            7th and 8th grade
# 199519       Self-employed-incorporated                   11th grade
# 199520                  Not in universe   Some college but no degree
# 199521                  Not in universe                   10th grade
# 199522                          Private         High school graduate
#
#               hs_college                      marital_stat  \
# 0        Not in universe                           Widowed
# 1        Not in universe                          Divorced
# 2            High school                     Never married
# 3        Not in universe                     Never married
# 4        Not in universe                     Never married
# ...                  ...                               ...
# 199518   Not in universe   Married-civilian spouse present
# 199519   Not in universe   Married-civilian spouse present
# 199520   Not in universe   Married-civilian spouse present
# 199521       High school                     Never married
# 199522   Not in universe                     Never married
#
#                        major_ind_code                        major_occ_code  \
# 0         Not in universe or children                       Not in universe
# 1                        Construction   Precision production craft & repair
# 2         Not in universe or children                       Not in universe
# 3         Not in universe or children                       Not in universe
# 4         Not in universe or children                       Not in universe
# ...                               ...                                   ...
# 199518    Not in universe or children                       Not in universe
# 199519   Business and repair services        Executive admin and managerial
# 199520    Not in universe or children                       Not in universe
# 199521    Not in universe or children                       Not in universe
# 199522        Medical except hospital                         Other service
#
#                               race hisp_origin      sex      union_member  \
# 0                            White   All other   Female   Not in universe
# 1                            White   All other     Male   Not in universe
# 2        Asian or Pacific Islander   All other   Female   Not in universe
# 3                            White   All other   Female   Not in universe
# 4                            White   All other   Female   Not in universe
# ...                            ...         ...      ...               ...
# 199518                       White   All other     Male   Not in universe
# 199519                       White   All other     Male   Not in universe
# 199520                       White   All other     Male   Not in universe
# 199521                       White   All other   Female   Not in universe
# 199522                       Black   All other   Female                No
#
#         ...   region_prev_res    state_prev_res  \
# 0       ...   Not in universe   Not in universe
# 1       ...             South          Arkansas
# 2       ...   Not in universe   Not in universe
# 3       ...   Not in universe   Not in universe
# 4       ...   Not in universe   Not in universe
# ...     ...               ...               ...
# 199518  ...   Not in universe   Not in universe
# 199519  ...   Not in universe   Not in universe
# 199520  ...   Not in universe   Not in universe
# 199521  ...   Not in universe   Not in universe
# 199522  ...   Not in universe   Not in universe
#
#                                   det_hh_fam_stat  \
# 0        Other Rel 18+ ever marr not in subfamily
# 1                                     Householder
# 2         Child 18+ never marr Not in a subfamily
# 3           Child <18 never marr not in subfamily
# 4           Child <18 never marr not in subfamily
# ...                                           ...
# 199518                                Householder
# 199519                                Householder
# 199520                                Householder
# 199521      Child <18 never marr not in subfamily
# 199522                      Nonfamily householder
#
#                            det_hh_summ                           mig_same  \
# 0        Other relative of householder   Not in universe under 1 year old
# 1                          Householder                                 No
# 2                    Child 18 or older   Not in universe under 1 year old
# 3         Child under 18 never married                                Yes
# 4         Child under 18 never married                                Yes
# ...                                ...                                ...
# 199518                     Householder   Not in universe under 1 year old
# 199519                     Householder                                Yes
# 199520                     Householder   Not in universe under 1 year old
# 199521    Child under 18 never married   Not in universe under 1 year old
# 199522                     Householder                                Yes
#
#                  fam_under_18    country_self  \
# 0             Not in universe   United-States
# 1             Not in universe   United-States
# 2             Not in universe         Vietnam
# 3        Both parents present   United-States
# 4        Both parents present   United-States
# ...                       ...             ...
# 199518        Not in universe   United-States
# 199519        Not in universe   United-States
# 199520        Not in universe         Germany
# 199521   Both parents present   United-States
# 199522        Not in universe   United-States
#
#                                          citizenship      vet_question  \
# 0                  Native- Born in the United States   Not in universe
# 1                  Native- Born in the United States   Not in universe
# 2                Foreign born- Not a citizen of U S    Not in universe
# 3                  Native- Born in the United States   Not in universe
# 4                  Native- Born in the United States   Not in universe
# ...                                              ...               ...
# 199518             Native- Born in the United States   Not in universe
# 199519             Native- Born in the United States   Not in universe
# 199520   Foreign born- U S citizen by naturalization   Not in universe
# 199521             Native- Born in the United States   Not in universe
# 199522           Foreign born- Not a citizen of U S    Not in universe
#
#        income_50k
# 0          -50000
# 1          -50000
# 2          -50000
# 3          -50000
# 4          -50000
# ...           ...
# 199518     -50000
# 199519     -50000
# 199520     -50000
# 199521     -50000
# 199522     -50000
#
# [199523 rows x 23 columns]

# %%
data_cat_copy_plot = data_cat.copy()

# %%
import plotly.express as px
# sns.scatterplot(x='major_occ_code',y='major_ind_code',data = data_cat)
# plt.xticks(rotation=45)
fig1 = px.treemap(data_cat_copy_plot,path=['major_occ_code','major_ind_code'])
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0c4709bd-9800-40e1-9a0f-7d4e3ee8d1bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c4709bd-9800-40e1-9a0f-7d4e3ee8d1bb")) {                    Plotly.newPlot(                        "0c4709bd-9800-40e1-9a0f-7d4e3ee8d1bb",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":[" Adm support including clerical/ Agriculture"," Executive admin and managerial/ Agriculture"," Farming forestry and fishing/ Agriculture"," Handlers equip cleaners etc / Agriculture"," Machine operators assmblrs & inspctrs/ Agriculture"," Other service/ Agriculture"," Precision production craft & repair/ Agriculture"," Professional specialty/ Agriculture"," Protective services/ Agriculture"," Sales/ Agriculture"," Technicians and related support/ Agriculture"," Transportation and material moving/ Agriculture"," Armed Forces/ Armed Forces"," Adm support including clerical/ Business and repair services"," Executive admin and managerial/ Business and repair services"," Farming forestry and fishing/ Business and repair services"," Handlers equip cleaners etc / Business and repair services"," Machine operators assmblrs & inspctrs/ Business and repair services"," Other service/ Business and repair services"," Precision production craft & repair/ Business and repair services"," Professional specialty/ Business and repair services"," Protective services/ Business and repair services"," Sales/ Business and repair services"," Technicians and related support/ Business and repair services"," Transportation and material moving/ Business and repair services"," Adm support including clerical/ Communications"," Executive admin and managerial/ Communications"," Handlers equip cleaners etc / Communications"," Machine operators assmblrs & inspctrs/ Communications"," Other service/ Communications"," Precision production craft & repair/ Communications"," Professional specialty/ Communications"," Sales/ Communications"," Technicians and related support/ Communications"," Transportation and material moving/ Communications"," Adm support including clerical/ Construction"," Executive admin and managerial/ Construction"," Farming forestry and fishing/ Construction"," Handlers equip cleaners etc / Construction"," Machine operators assmblrs & inspctrs/ Construction"," Other service/ Construction"," Precision production craft & repair/ Construction"," Professional specialty/ Construction"," Protective services/ Construction"," Sales/ Construction"," Technicians and related support/ Construction"," Transportation and material moving/ Construction"," Adm support including clerical/ Education"," Executive admin and managerial/ Education"," Farming forestry and fishing/ Education"," Handlers equip cleaners etc / Education"," Machine operators assmblrs & inspctrs/ Education"," Other service/ Education"," Precision production craft & repair/ Education"," Professional specialty/ Education"," Protective services/ Education"," Sales/ Education"," Technicians and related support/ Education"," Transportation and material moving/ Education"," Adm support including clerical/ Entertainment"," Executive admin and managerial/ Entertainment"," Farming forestry and fishing/ Entertainment"," Handlers equip cleaners etc / Entertainment"," Machine operators assmblrs & inspctrs/ Entertainment"," Other service/ Entertainment"," Precision production craft & repair/ Entertainment"," Professional specialty/ Entertainment"," Protective services/ Entertainment"," Sales/ Entertainment"," Technicians and related support/ Entertainment"," Transportation and material moving/ Entertai ...

# %%
fig2 = px.treemap(data_cat_copy_plot,path=['region_prev_res','state_prev_res'])
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d4f8956a-acb3-4927-ad5e-9ff7c5ef2831" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4f8956a-acb3-4927-ad5e-9ff7c5ef2831")) {                    Plotly.newPlot(                        "d4f8956a-acb3-4927-ad5e-9ff7c5ef2831",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":[" Abroad/ Abroad"," West/ Abroad"," South/ Alabama"," West/ Alaska"," West/ Arizona"," South/ Arkansas"," West/ California"," West/ Colorado"," Northeast/ Connecticut"," South/ Delaware"," South/ District of Columbia"," South/ Florida"," South/ Georgia"," West/ Idaho"," West/ Illinois"," Midwest/ Indiana"," Midwest/ Iowa"," Midwest/ Kansas"," Midwest/ Kentucky"," South/ Louisiana"," South/ Maine"," Northeast/ Maryland"," South/ Massachusetts"," Northeast/ Michigan"," Midwest/ Minnesota"," Midwest/ Mississippi"," South/ Missouri"," Midwest/ Montana"," West/ Nebraska"," Midwest/ Nevada"," West/ New Hampshire"," Northeast/ New Jersey"," Northeast/ New Mexico"," West/ New York"," Northeast/ North Carolina"," South/ North Dakota"," Northeast/ Not in universe"," Not in universe/ Not in universe"," South/ Not in universe"," Midwest/ Ohio"," Midwest/ Oklahoma"," South/ Oregon"," West/ Pennsylvania"," Northeast/ South Carolina"," South/ South Dakota"," Midwest/ Tennessee"," South/ Texas"," South/ Utah"," West/ Vermont"," Northeast/ Virginia"," West/ West Virginia"," South/ Wisconsin"," Midwest/ Wyoming"," Abroad"," Midwest"," Northeast"," Not in universe"," South"," West"],"labels":[" Abroad"," Abroad"," Alabama"," Alaska"," Arizona"," Arkansas"," California"," Colorado"," Connecticut"," Delaware"," District of Columbia"," Florida"," Georgia"," Idaho"," Illinois"," Indiana"," Iowa"," Kansas"," Kentucky"," Louisiana"," Maine"," Maryland"," Massachusetts"," Michigan"," Minnesota"," Mississippi"," Missouri"," Montana"," Nebraska"," Nevada"," New Hampshire"," New Jersey"," New Mexico"," New York"," North Carolina"," North Dakota"," Not in universe"," Not in universe"," Not in universe"," Ohio"," Oklahoma"," Oregon"," Pennsylvania"," South Carolina"," South Dakota"," Tennessee"," Texas"," Utah"," Vermont"," Virginia"," West Virginia"," Wisconsin"," Wyoming"," Abroad"," Midwest"," Northeast"," Not in universe"," South"," West"],"name":"","parents":[" Abroad"," West"," South"," West"," West"," South"," West"," West"," Northeast"," South"," South"," South"," South"," West"," West"," Midwest"," Midwest"," Midwest"," Midwest"," South"," South"," Northeast"," South"," Northeast"," Midwest"," Midwest"," South"," Midwest"," West"," Midwest"," West"," Northeast"," Northeast"," West"," Northeast"," South"," Northeast"," Not in universe"," South"," Midwest"," Midwest"," South"," West"," Northeast"," South"," Midwest"," South"," South"," West"," Northeast"," West"," South"," Midwest","","","","","",""],"values":[530,141,216,290,243,205,1714,239,117,73,116,849,227,31,180,533,189,149,244,192,167,136,151,441,576,204,175,226,178,174,242,75,463,195,812,499,440,183750,268,211,626,236,199,95,138,202,209,1063,191,126,231,105,241,530,3575,2705,183750,4889,4074],"type":"treemap"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white"," ...

# %%
fig3 = px.treemap(data_cat_copy_plot,path=["det_hh_summ","det_hh_fam_stat"])
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="096c3c74-bc49-4ebb-bdfd-76ed476bf833" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("096c3c74-bc49-4ebb-bdfd-76ed476bf833")) {                    Plotly.newPlot(                        "096c3c74-bc49-4ebb-bdfd-76ed476bf833",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":[" Child 18 or older/ Child 18+ ever marr Not in a subfamily"," Child 18 or older/ Child 18+ ever marr RP of subfamily"," Child 18 or older/ Child 18+ never marr Not in a subfamily"," Child 18 or older/ Child 18+ never marr RP of subfamily"," Child 18 or older/ Child 18+ spouse of subfamily RP"," Child under 18 ever married/ Child <18 ever marr RP of subfamily"," Child under 18 ever married/ Child <18 ever marr not in subfamily"," Child under 18 never married/ Child <18 never marr RP of subfamily"," Child under 18 never married/ Child <18 never marr not in subfamily"," Child under 18 ever married/ Child <18 spouse of subfamily RP"," Nonrelative of householder/ Child under 18 of RP of unrel subfamily"," Other relative of householder/ Grandchild 18+ ever marr RP of subfamily"," Other relative of householder/ Grandchild 18+ ever marr not in subfamily"," Other relative of householder/ Grandchild 18+ never marr RP of subfamily"," Other relative of householder/ Grandchild 18+ never marr not in subfamily"," Other relative of householder/ Grandchild 18+ spouse of subfamily RP"," Other relative of householder/ Grandchild <18 ever marr not in subfamily"," Other relative of householder/ Grandchild <18 never marr RP of subfamily"," Other relative of householder/ Grandchild <18 never marr child of subfamily RP"," Other relative of householder/ Grandchild <18 never marr not in subfamily"," Householder/ Householder"," Child 18 or older/ In group quarters"," Child under 18 never married/ In group quarters"," Group Quarters- Secondary individual/ In group quarters"," Householder/ In group quarters"," Nonrelative of householder/ In group quarters"," Other relative of householder/ In group quarters"," Spouse of householder/ In group quarters"," Householder/ Nonfamily householder"," Other relative of householder/ Other Rel 18+ ever marr RP of subfamily"," Other relative of householder/ Other Rel 18+ ever marr not in subfamily"," Other relative of householder/ Other Rel 18+ never marr RP of subfamily"," Other relative of householder/ Other Rel 18+ never marr not in subfamily"," Other relative of householder/ Other Rel 18+ spouse of subfamily RP"," Other relative of householder/ Other Rel <18 ever marr RP of subfamily"," Other relative of householder/ Other Rel <18 ever marr not in subfamily"," Other relative of householder/ Other Rel <18 never marr child of subfamily RP"," Other relative of householder/ Other Rel <18 never marr not in subfamily"," Other relative of householder/ Other Rel <18 never married RP of subfamily"," Other relative of householder/ Other Rel <18 spouse of subfamily RP"," Nonrelative of householder/ RP of unrelated subfamily"," Nonrelative of householder/ Secondary individual"," Nonrelative of householder/ Spouse of RP of unrelated subfamily"," Spouse of householder/ Spouse of householder"," Child 18 or older"," Child under 18 ever married"," Child under 18 never married"," Group Quarters- Secondary individual"," Householder"," Nonrelative of householder"," Other relative of householder"," Spouse of householder"],"labels":[" Child 18+ ever marr Not in a subfamily"," Child 18+ ever marr RP of subfamily"," Child 18+ never marr Not in a subfamily"," Child 18+ never marr RP of subfamily"," Child 18+ spouse of subfamily RP"," Chi ...

# %%
fig4 = px.treemap(data_cat_copy_plot,path=[ "citizenship","country_self"])
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ce62df87-f55a-43ae-982c-df81bac85ae1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce62df87-f55a-43ae-982c-df81bac85ae1")) {                    Plotly.newPlot(                        "ce62df87-f55a-43ae-982c-df81bac85ae1",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":[" Foreign born- Not a citizen of U S / Cambodia"," Foreign born- U S citizen by naturalization/ Cambodia"," Native- Born abroad of American Parent(s)/ Cambodia"," Foreign born- Not a citizen of U S / Canada"," Foreign born- U S citizen by naturalization/ Canada"," Native- Born abroad of American Parent(s)/ Canada"," Native- Born in the United States/ Canada"," Foreign born- Not a citizen of U S / China"," Foreign born- U S citizen by naturalization/ China"," Native- Born abroad of American Parent(s)/ China"," Foreign born- Not a citizen of U S / Columbia"," Foreign born- U S citizen by naturalization/ Columbia"," Native- Born abroad of American Parent(s)/ Columbia"," Foreign born- Not a citizen of U S / Cuba"," Foreign born- U S citizen by naturalization/ Cuba"," Native- Born abroad of American Parent(s)/ Cuba"," Foreign born- Not a citizen of U S / Dominican-Republic"," Foreign born- U S citizen by naturalization/ Dominican-Republic"," Native- Born abroad of American Parent(s)/ Dominican-Republic"," Foreign born- Not a citizen of U S / Ecuador"," Foreign born- U S citizen by naturalization/ Ecuador"," Native- Born abroad of American Parent(s)/ Ecuador"," Foreign born- Not a citizen of U S / El-Salvador"," Foreign born- U S citizen by naturalization/ El-Salvador"," Native- Born abroad of American Parent(s)/ El-Salvador"," Foreign born- Not a citizen of U S / England"," Foreign born- U S citizen by naturalization/ England"," Native- Born abroad of American Parent(s)/ England"," Foreign born- Not a citizen of U S / France"," Foreign born- U S citizen by naturalization/ France"," Native- Born abroad of American Parent(s)/ France"," Foreign born- Not a citizen of U S / Germany"," Foreign born- U S citizen by naturalization/ Germany"," Native- Born abroad of American Parent(s)/ Germany"," Foreign born- Not a citizen of U S / Greece"," Foreign born- U S citizen by naturalization/ Greece"," Native- Born abroad of American Parent(s)/ Greece"," Foreign born- Not a citizen of U S / Guatemala"," Foreign born- U S citizen by naturalization/ Guatemala"," Native- Born abroad of American Parent(s)/ Guatemala"," Foreign born- Not a citizen of U S / Haiti"," Foreign born- U S citizen by naturalization/ Haiti"," Native- Born abroad of American Parent(s)/ Haiti"," Foreign born- Not a citizen of U S / Holand-Netherlands"," Foreign born- U S citizen by naturalization/ Holand-Netherlands"," Native- Born abroad of American Parent(s)/ Holand-Netherlands"," Foreign born- Not a citizen of U S / Honduras"," Foreign born- U S citizen by naturalization/ Honduras"," Native- Born abroad of American Parent(s)/ Honduras"," Foreign born- Not a citizen of U S / Hong Kong"," Foreign born- U S citizen by naturalization/ Hong Kong"," Native- Born abroad of American Parent(s)/ Hong Kong"," Foreign born- Not a citizen of U S / Hungary"," Foreign born- U S citizen by naturalization/ Hungary"," Native- Born abroad of American Parent(s)/ Hungary"," Foreign born- Not a citizen of U S / India"," Foreign born- U S citizen by naturalization/ India"," Native- Born abroad of American Parent(s)/ India"," Foreign born- Not a citizen of U S / Iran"," Foreign born- U S citizen by naturalization/ Iran"," Native- Born abroad of American Parent(s)/ Iran"," Foreign born- Not a cit ...

# %%
data_cat_copy_plot.columns.tolist()
# Out:
# ['class_worker',
#  'education',
#  'hs_college',
#  'marital_stat',
#  'major_ind_code',
#  'major_occ_code',
#  'race',
#  'hisp_origin',
#  'sex',
#  'union_member',
#  'unemp_reason',
#  'full_or_part_emp',
#  'tax_filer_stat',
#  'region_prev_res',
#  'state_prev_res',
#  'det_hh_fam_stat',
#  'det_hh_summ',
#  'mig_same',
#  'fam_under_18',
#  'country_self',
#  'citizenship',
#  'vet_question',
#  'income_50k']

# %%
fig_cat1 = px.parallel_categories(data_cat_copy_plot[['major_ind_code','major_occ_code']])
fig_cat1.update_layout(width=1000)
fig_cat1.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
fig_cat2 = px.parallel_categories(data_cat_copy_plot[['region_prev_res','state_prev_res']])
fig_cat2.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
fig_cat3 = px.parallel_categories(data_cat_copy_plot[['country_self','citizenship']])
fig_cat3.update_layout(width=800)
fig_cat3.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
fig_cat4 = px.parallel_categories(data_cat_copy_plot[['hs_college','education']])
fig_cat4.update_layout(width=800)
fig_cat4.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Check imbalance data by groupby

# %%
data_cat_copy = data_cat
for col in data_cat_copy.columns.tolist():
  counts = data_cat_copy.groupby(col).size()
  imbalance_ratio1 = counts/counts.sum()
  print(str(col)+'has max imbanance proportion: '+str(np.round(np.max(imbalance_ratio1),2)))
# Out:
# class_workerhas max imbanance proportion: 0.5
# educationhas max imbanance proportion: 0.24
# hs_collegehas max imbanance proportion: 0.94
# marital_stathas max imbanance proportion: 0.43
# major_ind_codehas max imbanance proportion: 0.5
# major_occ_codehas max imbanance proportion: 0.5
# racehas max imbanance proportion: 0.84
# hisp_originhas max imbanance proportion: 0.86
# sexhas max imbanance proportion: 0.52
# union_memberhas max imbanance proportion: 0.9
# unemp_reasonhas max imbanance proportion: 0.97
# full_or_part_emphas max imbanance proportion: 0.62
# tax_filer_stathas max imbanance proportion: 0.38
# region_prev_reshas max imbanance proportion: 0.92
# state_prev_reshas max imbanance proportion: 0.92
# det_hh_fam_stathas max imbanance proportion: 0.27
# det_hh_summhas max imbanance proportion: 0.38
# mig_samehas max imbanance proportion: 0.51
# fam_under_18has max imbanance proportion: 0.72
# country_selfhas max imbanance proportion: 0.9
# citizenshiphas max imbanance proportion: 0.89
# vet_questionhas max imbanance proportion: 0.99
# income_50khas max imbanance proportion: 0.94

# %% [markdown]
# ### For categorical variables.
#
# * We applied Cramer's V method

# %%
def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x, y)
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k - 1) * (r - 1)) / (n - 1))
    rcorr = r - ((r - 1) ** 2) / (n - 1)
    kcorr = k - ((k - 1) ** 2) / (n - 1)
    return np.sqrt(phi2corr / min((kcorr - 1), (rcorr - 1)))

# %%
corr_cate = np.zeros((len(data_cat.columns), len(data_cat.columns)))
for i, col1 in enumerate(data_cat.columns):
    for j, col2 in enumerate(data_cat.columns):
        corr_cate[i, j] = cramers_v(data_cat[col1], data_cat[col2])

corr_df_cate = pd.DataFrame(corr_cate, columns=data_cat.columns, index=data_cat.columns)

# %%
sns.heatmap(corr_df_cate,annot=False, fmt = ".2f", cmap = "coolwarm")
# plt.title('correlation between the categorical variables')
plt.tight_layout()
plt.show()
data_cat.nunique()
# Out:
# class_worker         9
# education           17
# hs_college           3
# marital_stat         7
# major_ind_code      24
# major_occ_code      15
# race                 5
# hisp_origin         10
# sex                  2
# union_member         3
# unemp_reason         6
# full_or_part_emp     8
# tax_filer_stat       6
# region_prev_res      6
# state_prev_res      50
# det_hh_fam_stat     38
# det_hh_summ          8
# mig_same             3
# fam_under_18         5
# country_self        42
# citizenship          5
# vet_question         3
# income_50k           2
# dtype: int64

# %% [markdown]
# * Noticed that "major_ind_code" and "major_occ_code" have high correlation, "major_occ_code" has less classes, then we may drop "major_ind_code".
#
# * Noticed that "region_prev_res" and "state_prev_res" have high correlation, "region_prev_res" has less classes, then we may drop "state_prev_res".
#
# * Noticed that "det_hh_fam_stat" and "det_hh_summ" have high correlation, "det_hh_summ" has less classes, then we may drop "det_hh_fam_stat".
#
# * Noticed that "country_self" and "citizenship" have high correlation, "citizenship" has less classes, then we may drop "country_self".

# %%
corr_pairs = corr_df_cate.stack().reset_index()
corr_pairs.columns = ['v1','v2','corr']
corr_pairs = corr_pairs.loc[corr_pairs['v1']<corr_pairs['v2']]
corr_pairs = corr_pairs.sort_values('corr',ascending=False)
corr_pairs_new = corr_pairs[['v1','v2','corr']].reset_index(drop=True)
corr_pairs_new
# Out:
#                   v1               v2      corr
# 0    det_hh_fam_stat      det_hh_summ  0.976125
# 1    region_prev_res   state_prev_res  0.952950
# 2    det_hh_fam_stat     fam_under_18  0.723567
# 3        citizenship     country_self  0.718230
# 4           mig_same  region_prev_res  0.707093
# ..               ...              ...       ...
# 248         mig_same              sex  0.005243
# 249  region_prev_res     vet_question  0.005043
# 250     unemp_reason     vet_question  0.003808
# 251              sex   state_prev_res  0.002946
# 252   state_prev_res     vet_question  0.000000
#
# [253 rows x 3 columns]

# %%
data_cat = data_cat.drop(['major_ind_code', 'state_prev_res', 'det_hh_fam_stat', 'country_self'], axis=1)

# %%
data_cat
# Out:
#                            class_worker                    education  \
# 0                       Not in universe         High school graduate
# 1        Self-employed-not incorporated   Some college but no degree
# 2                       Not in universe                   10th grade
# 3                       Not in universe                     Children
# 4                       Not in universe                     Children
# ...                                 ...                          ...
# 199518                  Not in universe            7th and 8th grade
# 199519       Self-employed-incorporated                   11th grade
# 199520                  Not in universe   Some college but no degree
# 199521                  Not in universe                   10th grade
# 199522                          Private         High school graduate
#
#               hs_college                      marital_stat  \
# 0        Not in universe                           Widowed
# 1        Not in universe                          Divorced
# 2            High school                     Never married
# 3        Not in universe                     Never married
# 4        Not in universe                     Never married
# ...                  ...                               ...
# 199518   Not in universe   Married-civilian spouse present
# 199519   Not in universe   Married-civilian spouse present
# 199520   Not in universe   Married-civilian spouse present
# 199521       High school                     Never married
# 199522   Not in universe                     Never married
#
#                               major_occ_code                        race  \
# 0                            Not in universe                       White
# 1        Precision production craft & repair                       White
# 2                            Not in universe   Asian or Pacific Islander
# 3                            Not in universe                       White
# 4                            Not in universe                       White
# ...                                      ...                         ...
# 199518                       Not in universe                       White
# 199519        Executive admin and managerial                       White
# 199520                       Not in universe                       White
# 199521                       Not in universe                       White
# 199522                         Other service                       Black
#
#        hisp_origin      sex      union_member      unemp_reason  \
# 0        All other   Female   Not in universe   Not in universe
# 1        All other     Male   Not in universe   Not in universe
# 2        All other   Female   Not in universe   Not in universe
# 3        All other   Female   Not in universe   Not in universe
# 4        All other   Female   Not in universe   Not in universe
# ...            ...      ...               ...               ...
# 199518   All other     Male   Not in universe   Not in universe
# 199519   All other     Male   Not in universe   Not in universe
# 199520   All other     Male   Not in universe   Not in universe
# 199521   All other   Female   Not in universe   Not in universe
# 199522   All other   Female                No   Not in universe
#
#                  full_or_part_emp                 tax_filer_stat  \
# 0              Not in labor force                       Nonfiler
# 1        Children or Armed Forces              Head of household
# 2              Not in labor force                       Nonfiler
# 3        Children or Armed Forces                       Nonfiler
# 4        Children or Armed Forces                       Nonfiler
# ...                           ...                            ...
# 199518         Not in labor force                 Joint both 65+
# 199519   Children or Armed Forces   Joint one under 65 & one 65+
# 199520   Children or Armed Forces            Joint both under 65
# 199521         Not in labor force                       Nonfiler
# 199522   Children or Armed Forces                         Single
#
#          region_prev_res                     det_hh_summ  \
# 0        Not in universe   Other relative of householder
# 1                  South                     Householder
# 2        Not in universe               Child 18 or older
# 3        Not in universe    Child under 18 never married
# 4        Not in universe    Child under 18 never married
# ...                  ...                             ...
# 199518   Not in universe                     Householder
# 199519   Not in universe                     Householder
# 199520   Not in universe                     Householder
# 199521   Not in universe    Child under 18 never married
# 199522   Not in universe                     Householder
#
#                                  mig_same           fam_under_18  \
# 0        Not in universe under 1 year old        Not in universe
# 1                                      No        Not in universe
# 2        Not in universe under 1 year old        Not in universe
# 3                                     Yes   Both parents present
# 4                                     Yes   Both parents present
# ...                                   ...                    ...
# 199518   Not in universe under 1 year old        Not in universe
# 199519                                Yes        Not in universe
# 199520   Not in universe under 1 year old        Not in universe
# 199521   Not in universe under 1 year old   Both parents present
# 199522                                Yes        Not in universe
#
#                                          citizenship      vet_question  \
# 0                  Native- Born in the United States   Not in universe
# 1                  Native- Born in the United States   Not in universe
# 2                Foreign born- Not a citizen of U S    Not in universe
# 3                  Native- Born in the United States   Not in universe
# 4                  Native- Born in the United States   Not in universe
# ...                                              ...               ...
# 199518             Native- Born in the United States   Not in universe
# 199519             Native- Born in the United States   Not in universe
# 199520   Foreign born- U S citizen by naturalization   Not in universe
# 199521             Native- Born in the United States   Not in universe
# 199522           Foreign born- Not a citizen of U S    Not in universe
#
#        income_50k
# 0          -50000
# 1          -50000
# 2          -50000
# 3          -50000
# 4          -50000
# ...           ...
# 199518     -50000
# 199519     -50000
# 199520     -50000
# 199521     -50000
# 199522     -50000
#
# [199523 rows x 19 columns]

# %% [markdown]
# ## We indentify whether some categorical variables is highly imbalanced
#
# * We use the [Shannon entropy to measure balance.](https://stats.stackexchange.com/questions/239973/a-general-measure-of-data-set-imbalance)

# %%
def shannon_entropy(df):
    imbalance_score_dict = {}
    for col in df.columns:
        value_counts = df[col].value_counts(normalize=True)
        target_entropy = entropy(value_counts, base=2)
        max_entropy = np.log2(len(value_counts))
        imbalance_score_dict[col] = 1 - target_entropy / max_entropy
    imbalance_score_df = pd.DataFrame(data=imbalance_score_dict, index=['Imbalanced_Score']).T
    imbalance_score_df = imbalance_score_df.sort_values('Imbalanced_Score', ascending=False)
    return imbalance_score_df


shannon_entropy(data_cat)
# Out:
#                   Imbalanced_Score
# vet_question              0.944768
# unemp_reason              0.899451
# region_prev_res           0.781049
# hs_college                0.746322
# hisp_origin               0.717359
# citizenship               0.707961
# union_member              0.675017
# income_50k                0.664439
# race                      0.622310
# fam_under_18              0.494688
# full_or_part_emp          0.480735
# class_worker              0.451928
# marital_stat              0.392129
# major_occ_code            0.316522
# det_hh_summ               0.273439
# tax_filer_stat            0.229902
# education                 0.218234
# mig_same                  0.171647
# sex                       0.001293

# %% [markdown]
# ### To avoid the effect of highly imbalanced data, we shall drop ['vet_question','unemp_reason','region_prev_res','hs_college','hisp_origin'] which have high imbalanced score.

# %%
data_cat = data_cat.drop(['vet_question', 'unemp_reason', 'region_prev_res', 'hs_college', 'hisp_origin'], axis=1)
data_cat
# Out:
#                            class_worker                    education  \
# 0                       Not in universe         High school graduate
# 1        Self-employed-not incorporated   Some college but no degree
# 2                       Not in universe                   10th grade
# 3                       Not in universe                     Children
# 4                       Not in universe                     Children
# ...                                 ...                          ...
# 199518                  Not in universe            7th and 8th grade
# 199519       Self-employed-incorporated                   11th grade
# 199520                  Not in universe   Some college but no degree
# 199521                  Not in universe                   10th grade
# 199522                          Private         High school graduate
#
#                             marital_stat  \
# 0                                Widowed
# 1                               Divorced
# 2                          Never married
# 3                          Never married
# 4                          Never married
# ...                                  ...
# 199518   Married-civilian spouse present
# 199519   Married-civilian spouse present
# 199520   Married-civilian spouse present
# 199521                     Never married
# 199522                     Never married
#
#                               major_occ_code                        race  \
# 0                            Not in universe                       White
# 1        Precision production craft & repair                       White
# 2                            Not in universe   Asian or Pacific Islander
# 3                            Not in universe                       White
# 4                            Not in universe                       White
# ...                                      ...                         ...
# 199518                       Not in universe                       White
# 199519        Executive admin and managerial                       White
# 199520                       Not in universe                       White
# 199521                       Not in universe                       White
# 199522                         Other service                       Black
#
#             sex      union_member           full_or_part_emp  \
# 0        Female   Not in universe         Not in labor force
# 1          Male   Not in universe   Children or Armed Forces
# 2        Female   Not in universe         Not in labor force
# 3        Female   Not in universe   Children or Armed Forces
# 4        Female   Not in universe   Children or Armed Forces
# ...         ...               ...                        ...
# 199518     Male   Not in universe         Not in labor force
# 199519     Male   Not in universe   Children or Armed Forces
# 199520     Male   Not in universe   Children or Armed Forces
# 199521   Female   Not in universe         Not in labor force
# 199522   Female                No   Children or Armed Forces
#
#                        tax_filer_stat                     det_hh_summ  \
# 0                            Nonfiler   Other relative of householder
# 1                   Head of household                     Householder
# 2                            Nonfiler               Child 18 or older
# 3                            Nonfiler    Child under 18 never married
# 4                            Nonfiler    Child under 18 never married
# ...                               ...                             ...
# 199518                 Joint both 65+                     Householder
# 199519   Joint one under 65 & one 65+                     Householder
# 199520            Joint both under 65                     Householder
# 199521                       Nonfiler    Child under 18 never married
# 199522                         Single                     Householder
#
#                                  mig_same           fam_under_18  \
# 0        Not in universe under 1 year old        Not in universe
# 1                                      No        Not in universe
# 2        Not in universe under 1 year old        Not in universe
# 3                                     Yes   Both parents present
# 4                                     Yes   Both parents present
# ...                                   ...                    ...
# 199518   Not in universe under 1 year old        Not in universe
# 199519                                Yes        Not in universe
# 199520   Not in universe under 1 year old        Not in universe
# 199521   Not in universe under 1 year old   Both parents present
# 199522                                Yes        Not in universe
#
#                                          citizenship income_50k
# 0                  Native- Born in the United States     -50000
# 1                  Native- Born in the United States     -50000
# 2                Foreign born- Not a citizen of U S      -50000
# 3                  Native- Born in the United States     -50000
# 4                  Native- Born in the United States     -50000
# ...                                              ...        ...
# 199518             Native- Born in the United States     -50000
# 199519             Native- Born in the United States     -50000
# 199520   Foreign born- U S citizen by naturalization     -50000
# 199521             Native- Born in the United States     -50000
# 199522           Foreign born- Not a citizen of U S      -50000
#
# [199523 rows x 14 columns]

# %%
for col in data_cat.columns:
    counts = data_cat[col].value_counts()
    if ' Not in universe' in counts:
        niu_proportion = counts[' Not in universe'] / data_cat.shape[0]
    elif ' Not in universe or children' in counts:
        niu_proportion = counts[' Not in universe or children'] / data_cat.shape[0]
    else:
        niu_proportion = 0
    print(col, np.round(niu_proportion, 2))
# Out:
# class_worker 0.5
# education 0
# marital_stat 0
# major_occ_code 0.5
# race 0
# sex 0
# union_member 0.9
# full_or_part_emp 0
# tax_filer_stat 0
# det_hh_summ 0
# mig_same 0
# fam_under_18 0.72
# citizenship 0
# income_50k 0

# %%
data_new = pd.concat([data_num, data_cat], axis=1)
data_new
# Out:
#         age  wage_per_hour  capital_gains  capital_losses  stock_dividends  \
# 0        73              0              0               0                0
# 1        58              0              0               0                0
# 2        18              0              0               0                0
# 3         9              0              0               0                0
# 4        10              0              0               0                0
# ...     ...            ...            ...             ...              ...
# 199518   87              0              0               0                0
# 199519   65              0           6418               0                9
# 199520   47              0              0               0              157
# 199521   16              0              0               0                0
# 199522   32              0              0               0                0
#
#         num_emp  own_or_self  weeks_worked  year  \
# 0             0            0             0    95
# 1             1            0            52    94
# 2             0            0             0    95
# 3             0            0             0    94
# 4             0            0             0    94
# ...         ...          ...           ...   ...
# 199518        0            0             0    95
# 199519        1            0            52    94
# 199520        6            0            52    95
# 199521        0            0             0    95
# 199522        6            0            52    94
#
#                            class_worker  ...                        race  \
# 0                       Not in universe  ...                       White
# 1        Self-employed-not incorporated  ...                       White
# 2                       Not in universe  ...   Asian or Pacific Islander
# 3                       Not in universe  ...                       White
# 4                       Not in universe  ...                       White
# ...                                 ...  ...                         ...
# 199518                  Not in universe  ...                       White
# 199519       Self-employed-incorporated  ...                       White
# 199520                  Not in universe  ...                       White
# 199521                  Not in universe  ...                       White
# 199522                          Private  ...                       Black
#
#             sex      union_member           full_or_part_emp  \
# 0        Female   Not in universe         Not in labor force
# 1          Male   Not in universe   Children or Armed Forces
# 2        Female   Not in universe         Not in labor force
# 3        Female   Not in universe   Children or Armed Forces
# 4        Female   Not in universe   Children or Armed Forces
# ...         ...               ...                        ...
# 199518     Male   Not in universe         Not in labor force
# 199519     Male   Not in universe   Children or Armed Forces
# 199520     Male   Not in universe   Children or Armed Forces
# 199521   Female   Not in universe         Not in labor force
# 199522   Female                No   Children or Armed Forces
#
#                        tax_filer_stat                     det_hh_summ  \
# 0                            Nonfiler   Other relative of householder
# 1                   Head of household                     Householder
# 2                            Nonfiler               Child 18 or older
# 3                            Nonfiler    Child under 18 never married
# 4                            Nonfiler    Child under 18 never married
# ...                               ...                             ...
# 199518                 Joint both 65+                     Householder
# 199519   Joint one under 65 & one 65+                     Householder
# 199520            Joint both under 65                     Householder
# 199521                       Nonfiler    Child under 18 never married
# 199522                         Single                     Householder
#
#                                  mig_same           fam_under_18  \
# 0        Not in universe under 1 year old        Not in universe
# 1                                      No        Not in universe
# 2        Not in universe under 1 year old        Not in universe
# 3                                     Yes   Both parents present
# 4                                     Yes   Both parents present
# ...                                   ...                    ...
# 199518   Not in universe under 1 year old        Not in universe
# 199519                                Yes        Not in universe
# 199520   Not in universe under 1 year old        Not in universe
# 199521   Not in universe under 1 year old   Both parents present
# 199522                                Yes        Not in universe
#
#                                          citizenship income_50k
# 0                  Native- Born in the United States     -50000
# 1                  Native- Born in the United States     -50000
# 2                Foreign born- Not a citizen of U S      -50000
# 3                  Native- Born in the United States     -50000
# 4                  Native- Born in the United States     -50000
# ...                                              ...        ...
# 199518             Native- Born in the United States     -50000
# 199519             Native- Born in the United States     -50000
# 199520   Foreign born- U S citizen by naturalization     -50000
# 199521             Native- Born in the United States     -50000
# 199522           Foreign born- Not a citizen of U S      -50000
#
# [199523 rows x 23 columns]

# %%
#data_new.to_excel('train_data_after_EDA.xlsx',index=False)
